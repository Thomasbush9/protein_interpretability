# %%
import torch 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path

# %%
att_132_path = Path("/Users/thomasbush/Downloads/seq_00132_attention.pt")
att_132 = torch.load(att_132_path)

# %%
att_132["step_0"].keys()
# Out:
# dict_keys(['pairformer_layer_0', 'pairformer_layer_11', 'pairformer_layer_23', 'pairformer_layer_34', 'pairformer_layer_44', 'pairformer_layer_55', 'pairformer_layer_63'])

# %%
att_l23 = att_132["step_0"]["pairformer_layer_23"]

# %%
plt.figure()
plt.imshow(att_132["step_10"]["pairformer_layer_63"].squeeze().cpu().numpy()[-1])
